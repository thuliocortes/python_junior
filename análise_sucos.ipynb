# %% [markdown]
# <a href="https://colab.research.google.com/github/thuliocortes/python_junior/blob/main/an%C3%A1lise_sucos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('sucos.csv')

# %%
dados.head(2)
# Out:
#                         Desc_Cliente Desc_Cidade Desc_Estado Cod_Estado  \
# 0  Supermercados Bom e Barato Goiais      Goiais      Goiais         GO
# 1  Supermercados Bom e Barato Goiais      Goiais      Goiais         GO
#
#    Desc_Segmento               Desc_Fabrica Desc_Vendedor    Desc_Gerente  \
# 0  Supermercados  FAbrica do Rio de Janeiro  Willian Show  Taylor Maxwell
# 1  Supermercados  FAbrica do Rio de Janeiro  Willian Show  Taylor Maxwell
#
#      Desc_Diretor                         Desc_Produto  ... Numero_Ano  \
# 0  Taylor Maxwell  Linha Citros - 1 Litro - Lima/Limao  ...       2013
# 1  Taylor Maxwell   Linha Citros - 700 ml - Lima/Limao  ...       2013
#
#    Faturamento Unidade_Vendida Quantidade_Vendida     Imposto Custo_Variavel  \
# 0  6167.152832           410.0         410.186432  553.751648     820.372864
# 1  3606.521484           342.0         239.875046  323.831329     479.750092
#
#    Custo_Frete Custo_Fixo  Meta_Faturamento  Meta_Custo
# ...

# %%
dados[{"Faturamento",'Unidade_Vendida', 'Custo_Variavel', 'Quantidade_Vendida'}].describe()
# Out:
#        Unidade_Vendida   Faturamento  Custo_Variavel  Quantidade_Vendida
# count     13777.000000  13777.000000    13777.000000        13777.000000
# mean        342.360383   5212.271440     1970.226633          300.372995
# std         225.443380   5248.374899     2157.909507          281.680366
# min          55.000000    281.749237       97.152359           21.262060
# 25%         190.000000   2017.007446      661.328064          119.596420
# 50%         279.000000   3528.525391     1244.011719          211.442139
# 75%         426.000000   6449.190918     2451.548096          380.906342
# max        2587.000000  72409.343750    26416.056640         3033.131958

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
sns.set_palette("CMRmap_r")
ax = sns.barplot(x = "Desc_Segmento", y = "Faturamento", data = dados)
ax.figure.set_size_inches(12,6)
ax.set_title('Faturamento por Segmento',fontsize = '18')
# Out:
# Text(0.5, 1.0, 'Faturamento por Segmento')

# %%
ax = sns.barplot(x = "Desc_Estado", y = "Faturamento", data = dados)
ax.figure.set_size_inches(18,8)
ax.set_title('Faturamento por Estado',fontsize = '18')
# Out:
# Text(0.5, 1.0, 'Faturamento por Estado')

# %%
ax = sns.barplot(x = "Desc_Fabrica", y = "Faturamento", data = dados)
ax.figure.set_size_inches(12,6)
ax.set_title('Faturamento por Fábrica',fontsize = '15')
# Out:
# Text(0.5, 1.0, 'Faturamento por Fábrica')

# %%
dados.columns
# Out:
# Index(['Desc_Cliente', 'Desc_Cidade', 'Desc_Estado', 'Cod_Estado',
#        'Desc_Segmento', 'Desc_Fabrica', 'Desc_Vendedor', 'Desc_Gerente',
#        'Desc_Diretor', 'Desc_Produto', 'Desc_Marca', 'Desc_Categoria',
#        'Atr_Tamanho', 'Atr_Sabor', 'Data', 'Nome_Mes', 'Nome_Trimestre',
#        'Nome_Semestre', 'Numero_Ano', 'Faturamento', 'Unidade_Vendida',
#        'Quantidade_Vendida', 'Imposto', 'Custo_Variavel', 'Custo_Frete',
#        'Custo_Fixo', 'Meta_Faturamento', 'Meta_Custo'],
#       dtype='object')

# %%
sns.set_palette("CMRmap")
ax = sns.lineplot(x = 'Data', y= 'Faturamento', data = dados)
ax.figure.set_size_inches(40,6)
ax.set_title('Evolução do Faturamento',fontsize = '30')
# Out:
# Text(0.5, 1.0, 'Evolução do Faturamento')
