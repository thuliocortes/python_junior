# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/racas_caes_base.csv')

# %%
dados
# Out:
#                                          BreedName  \
# 0                                    Affenpinscher
# 1                                     Afghan Hound
# 2                              African Hunting Dog
# 3                                 Airedale Terrier
# 4                                           Akbash
# 5                                            Akita
# 6                                 Alaskan Malamute
# 7                                 American Bulldog
# 8                              American Eskimo Dog
# 9                        American Hairless Terrier
# 10                  American Staffordshire Terrier
# 11                          American Water Spaniel
# 12                              Anatolian Shepherd
# 13                          Appenzell Mountain Dog
# 14               Australian Cattle Dog/Blue Heeler
# 15                               Australian Kelpie
# 16                             Australian Shepherd
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   BreedName              250 non-null    object
#  1   AltBreedName           35 non-null     object
#  2   Group1                 245 non-null    object
#  3   Group2                 246 non-null    object
#  4   MaleWtKg               249 non-null    float64
#  5   Temperment             249 non-null    object
#  6   AvgPupPrice            245 non-null    float64
#  7   Intelligence           149 non-null    float64
#  8   Watchdog               244 non-null    float64
#  9   MalaysiaGuardedDog     6 non-null      float64
#  10  MalaysiaProhibitedDog  9 non-null      float64
#  11  MalaysiaPopularity     8 non-null      float64
#  12  PopularityUS2017       203 non-null    float64
# dtypes: float64(8), object(5)
# memory usage: 25.5+ KB

# %%
dados.drop(['AltBreedName', 'MalaysiaGuardedDog', 'MalaysiaProhibitedDog', 'MalaysiaPopularity'], axis = 1, inplace = True)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BreedName         250 non-null    object
#  1   Group1            245 non-null    object
#  2   Group2            246 non-null    object
#  3   MaleWtKg          249 non-null    float64
#  4   Temperment        249 non-null    object
#  5   AvgPupPrice       245 non-null    float64
#  6   Intelligence      149 non-null    float64
#  7   Watchdog          244 non-null    float64
#  8   PopularityUS2017  203 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 17.7+ KB

# %%
pd.set_option('display.max_rows', 250)

# %%
dados
# Out:
#                                          BreedName        Group1      Group2  \
# 0                                    Affenpinscher           Toy   Companion
# 1                                     Afghan Hound      Sporting       Sight
# 2                              African Hunting Dog           NaN         NaN
# 3                                 Airedale Terrier       Terrier     Terrier
# 4                                           Akbash       Working    Guardian
# 5                                            Akita       Working     Herding
# 6                                 Alaskan Malamute       Working    Northern
# 7                                 American Bulldog       Working    Guardian
# 8                              American Eskimo Dog  Non Sporting    Northern
# 9                        American Hairless Terrier       Terrier     Terrier
# 10                  American Staffordshire Terrier       Terrier     Terrier
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BreedName         250 non-null    object
#  1   Group1            245 non-null    object
#  2   Group2            246 non-null    object
#  3   MaleWtKg          249 non-null    float64
#  4   Temperment        249 non-null    object
#  5   AvgPupPrice       245 non-null    float64
#  6   Intelligence      149 non-null    float64
#  7   Watchdog          244 non-null    float64
#  8   PopularityUS2017  203 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 17.7+ KB

# %%
dados.dropna(subset= ['MaleWtKg', 'Temperment', 'AvgPupPrice'], inplace= True)

# %%
dados.columns = ['Nome', 'Tipo', 'Tipo 2', 'Peso', 'Temperamento', 'Preço', 'Inteligência', 
                 'Nota de guarda', 'Popularidade nos EUA']

# %%
dados_new = dados.drop([81])

# %%
dados_new['Preço'].sort_values()
# Out:
# 94      350.0
# 133     350.0
# 117     350.0
# 71      350.0
# 30      350.0
# 155     400.0
# 153     400.0
# 138     400.0
# 132     400.0
# 19      400.0
# 148     400.0
# 190     400.0
# 55      400.0
# 187     400.0
# 32      400.0
# 176     400.0
# 9       400.0
# 87      450.0
# 178     450.0
# 164     500.0
# 172     500.0
# 169     500.0
# 101     500.0
# 70      500.0
# 154     500.0
# 119     500.0
# 206     500.0
# 88      500.0
# 131     500.0
# 231     500.0
# 230     500.0
# 168     550.0
# 137     550.0
# 36      550.0
# 4       600.0
# 163     600.0
# 75      600.0
# 170     600.0
# 175     600.0
# 14      600.0
# 15      600.0
# 147     600.0
# 98      600.0
# 56      600.0
# 116     650.0
# 25      650.0
# 20      650.0
# 145     700.0
# 171     700.0
# 106     700.0
# 69      700.0
# 8       700.0
# 244     700.0
# 125     700.0
# 107     700.0
# 149     700.0
# 26      700.0
# 3       700.0
# 246     700.0
# 151     700.0
# 74      700.0
# 35      700.0
# ...

# %%
dados_new.to_csv('dados/racas_caes.csv', index= False)

# %%
dados_inteligencia = dados.copy()

# %%
dados_inteligencia.dropna(subset= ['Inteligência'], inplace = True)

# %%
dados_inteligencia.to_csv('dados/raca_caes_inteligencia.csv', index= False)

# %%
dados_popularidade = dados.copy()

# %%
dados_popularidade.dropna(subset= ['Popularidade nos EUA'], inplace= True)

# %%
dados_popularidade.to_csv('dados/racas_caes_popularidade.csv', index= False)
