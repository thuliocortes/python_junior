# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/racas_caes.csv')

# %%
pd.set_option('display.max_rows', 250)

# %%
dados
# Out:
#                                               Nome          Tipo      Tipo 2  \
# 0                                    Affenpinscher           Toy   Companion
# 1                                     Afghan Hound      Sporting       Sight
# 2                                 Airedale Terrier       Terrier     Terrier
# 3                                           Akbash       Working    Guardian
# 4                                            Akita       Working     Herding
# 5                                 Alaskan Malamute       Working    Northern
# 6                                 American Bulldog       Working    Guardian
# 7                              American Eskimo Dog  Non Sporting    Northern
# 8                        American Hairless Terrier       Terrier     Terrier
# 9                   American Staffordshire Terrier       Terrier     Terrier
# 10                          American Water Spaniel      Sporting         Gun
# ...

# %%
dados.value_counts('Tipo')
# Out:
# Tipo
# Working         48
# Sporting        40
# Herding         36
# Terrier         36
# Hound           34
# Non Sporting    27
# Toy             21
# Southern         1
# dtype: int64

# %%
dados.value_counts('Tipo 2')
# Out:
# Tipo 2
# Gun           40
# Terrier       38
# Herding       36
# Companion     35
# Guardian      32
# Northern      23
# Scenthound    19
# Sight         19
# Gun Dogs       1
# Southern       1
# dtype: int64

# %%
trabalho_esporte = ['Working', 'Herding', 'Sporting']
dados['Grupo Tipo'] = dados['Tipo'].apply(lambda x: 'Trabalho ou Esporte' if x in trabalho_esporte else 'Companhia')

# %%
dados.to_csv('dados/racas_caes.csv', index = 0)
