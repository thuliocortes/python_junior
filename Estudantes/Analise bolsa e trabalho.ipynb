# %%
import pandas as pd
import seaborn as sns

# %%
dados = pd.read_csv('dados/tabela_geral_estudantes.csv')
dados
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0   Female      21             2.0    Home    No       No          No      No
# 1     Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 2     Male      23             2.0    Home   Yes       No          No      No
# 3     Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4   Female      19             2.0    Home    No       No  Motorcycle      No
# ..      ...    ...             ...     ...   ...      ...         ...     ...
# 94    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 95  Female      19             2.0    Home    No       No  Motorcycle      No
# 96    Male      22             3.0  Hostel    No      Yes         Car     NaN
# 97  Female      21             2.0    Home   Yes       No          No      No
# 98    Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
#
# ...

# %%
dados.columns = ['Genero', 'Idade', 'Anos de Estudo', 'Moradia', 'Bolsa', 'Trabalho', 'Transporte', 'Fumante', 'Consome Alcool', 'Joga', 'Usa Cosmeticos', 'Assinaturas', 'Gastos Mensais']

# %%
dados.head(10)
# Out:
#     Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0  Female      21             2.0    Home    No       No          No      No
# 1    Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 2    Male      23             2.0    Home   Yes       No          No      No
# 3    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4  Female      19             2.0    Home    No       No  Motorcycle      No
# 5    Male      22             3.0  Hostel    No      Yes         Car     NaN
# 6  Female      21             2.0    Home   Yes       No          No      No
# 7    Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
# 8  Female      18             1.0    Home   Yes       No          No      No
# 9    Male      19             1.0    Home    No       No          No     NaN
#
#   Consome Alcool Joga Usa Cosmeticos Assinaturas  Gastos Mensais
# ...

# %% [markdown]
# # Informações Gerais sobre a base de dados

# %%
dados.value_counts('Consome Alcool')
# Out:
# Consome Alcool
# No     80
# Yes     8
# dtype: int64

# %%
dados.value_counts('Fumante')
# Out:
# Fumante
# No     70
# Yes    20
# dtype: int64

# %%
dados.value_counts('Assinaturas')
# Out:
# Assinaturas
# No     47
# Yes    44
# dtype: int64

# %%
dados.value_counts('Trabalho')
# Out:
# Trabalho
# No     67
# Yes    27
# dtype: int64

# %%
n0 = dados['Gastos Mensais'].mean()
n0
# Out:
# 214.94949494949495

# %% [markdown]
# # Gastos de Bolsistas que trabalham

# %%
selecao = (dados['Bolsa'] == 'Yes') & (dados['Trabalho'] == 'Yes')
bolsa_trabalho = dados[selecao]
bolsa_trabalho
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho Transporte Fumante  \
# 13  Female      22             4.0  Hostel   Yes      Yes        Car      No
# 20  Female      22             4.0    Home   Yes      Yes        Car     Yes
# 35    Male      22             NaN  Hostel   Yes      Yes        Car      No
# 38  Female      22             4.0  Hostel   Yes      Yes        NaN      No
# 43  Female      22             4.0  Hostel   Yes      Yes        Car      No
# 49  Female      22             4.0    Home   Yes      Yes        Car     Yes
# 59    Male      22             NaN  Hostel   Yes      Yes        Car      No
# 62  Female      22             4.0  Hostel   Yes      Yes        NaN      No
# 67  Female      22             4.0  Hostel   Yes      Yes        Car      No
# 84  Female      22             4.0  Hostel   Yes      Yes        Car      No
# 87  Female      22             4.0  Hostel   Yes      Yes        Car      No
#
# ...

# %%
bolsa_trabalho.shape[0]
# Out:
# 11

# %%
bolsa_trabalho.index = range(bolsa_trabalho.shape[0])
bolsa_trabalho
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho Transporte Fumante  \
# 0   Female      22             4.0  Hostel   Yes      Yes        Car      No
# 1   Female      22             4.0    Home   Yes      Yes        Car     Yes
# 2     Male      22             NaN  Hostel   Yes      Yes        Car      No
# 3   Female      22             4.0  Hostel   Yes      Yes        NaN      No
# 4   Female      22             4.0  Hostel   Yes      Yes        Car      No
# 5   Female      22             4.0    Home   Yes      Yes        Car     Yes
# 6     Male      22             NaN  Hostel   Yes      Yes        Car      No
# 7   Female      22             4.0  Hostel   Yes      Yes        NaN      No
# 8   Female      22             4.0  Hostel   Yes      Yes        Car      No
# 9   Female      22             4.0  Hostel   Yes      Yes        Car      No
# 10  Female      22             4.0  Hostel   Yes      Yes        Car      No
#
# ...

# %%
n1 = bolsa_trabalho['Gastos Mensais'].mean()
n1
# Out:
# 269.09090909090907

# %% [markdown]
# # Gastos de Bolsistas que não trabalha

# %%
dados
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0   Female      21             2.0    Home    No       No          No      No
# 1     Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 2     Male      23             2.0    Home   Yes       No          No      No
# 3     Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4   Female      19             2.0    Home    No       No  Motorcycle      No
# ..      ...    ...             ...     ...   ...      ...         ...     ...
# 94    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 95  Female      19             2.0    Home    No       No  Motorcycle      No
# 96    Male      22             3.0  Hostel    No      Yes         Car     NaN
# 97  Female      21             2.0    Home   Yes       No          No      No
# 98    Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
#
# ...

# %%
dados.shape[0]
# Out:
# 99

# %%
selecao = (dados['Bolsa'] == 'Yes') & (dados['Trabalho'] == 'No')
bolsa_sem_trabalho = dados[selecao]
bolsa_sem_trabalho.shape[0]
# Out:
# 14

# %%
bolsa_sem_trabalho.index = range(bolsa_sem_trabalho.shape[0])
bolsa_sem_trabalho
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0     Male      23             2.0    Home   Yes       No          No      No
# 1   Female      21             2.0    Home   Yes       No          No      No
# 2   Female      18             1.0    Home   Yes       No          No      No
# 3     Male      22             4.0    Home   Yes       No          No     Yes
# 4     Male      18             1.0    Home   Yes       No          No      No
# 5     Male      18             1.0  Hostel   Yes       No  Motorcycle      No
# 6   Female      19             2.0     NaN   Yes       No         NaN      No
# 7     Male      22             4.0    Home   Yes       No  Motorcycle     Yes
# 8     Male      18             1.0    Home   Yes       No          No      No
# 9     Male      23             2.0    Home   Yes       No          No      No
# 10  Female      21             2.0    Home   Yes       No          No      No
# ...

# %%
n2 = bolsa_sem_trabalho['Gastos Mensais'].mean()

# %%
n2
# Out:
# 194.28571428571428

# %% [markdown]
# # Gastos de quem Não tem bolsa e trabalha

# %%
dados
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0   Female      21             2.0    Home    No       No          No      No
# 1     Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 2     Male      23             2.0    Home   Yes       No          No      No
# 3     Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4   Female      19             2.0    Home    No       No  Motorcycle      No
# ..      ...    ...             ...     ...   ...      ...         ...     ...
# 94    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 95  Female      19             2.0    Home    No       No  Motorcycle      No
# 96    Male      22             3.0  Hostel    No      Yes         Car     NaN
# 97  Female      21             2.0    Home   Yes       No          No      No
# 98    Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
#
# ...

# %%
selecao = (dados['Bolsa'] == 'No') & (dados['Trabalho'] == 'Yes')
trabalha_sem_bolsa = dados[selecao]
trabalha_sem_bolsa
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 1     Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 5     Male      22             3.0  Hostel    No      Yes         Car     NaN
# 7     Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
# 19    Male      19             2.0  Hostel    No      Yes         Car     NaN
# 22  Female      22             4.0    Home    No      Yes          No      No
# 29    Male      22             3.0    Home    No      Yes         NaN     Yes
# 34  Female      21             4.0    Home    No      Yes  Motorcycle     NaN
# 42    Male      19             2.0    Home    No      Yes         NaN     Yes
# 51  Female      22             4.0    Home    No      Yes          No      No
# 58  Female      21             4.0    Home    No      Yes  Motorcycle     NaN
# 66    Male      19             2.0    Home    No      Yes         NaN     Yes
# ...

# %%
trabalha_sem_bolsa.shape[0]
# Out:
# 16

# %%
trabalha_sem_bolsa.index = range(trabalha_sem_bolsa.shape[0])
trabalha_sem_bolsa
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0     Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 1     Male      22             3.0  Hostel    No      Yes         Car     NaN
# 2     Male      22             3.0  Hostel    No      Yes  Motorcycle     Yes
# 3     Male      19             2.0  Hostel    No      Yes         Car     NaN
# 4   Female      22             4.0    Home    No      Yes          No      No
# 5     Male      22             3.0    Home    No      Yes         NaN     Yes
# 6   Female      21             4.0    Home    No      Yes  Motorcycle     NaN
# 7     Male      19             2.0    Home    No      Yes         NaN     Yes
# 8   Female      22             4.0    Home    No      Yes          No      No
# 9   Female      21             4.0    Home    No      Yes  Motorcycle     NaN
# 10    Male      19             2.0    Home    No      Yes         NaN     Yes
# ...

# %%
n3 = trabalha_sem_bolsa['Gastos Mensais'].mean()

# %%
n3
# Out:
# 208.75

# %% [markdown]
# # Gastos de quem não tem bolsa e não trabalha

# %%
dados.head()
# Out:
#     Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0  Female      21             2.0    Home    No       No          No      No
# 1    Male      25             3.0  Hostel    No      Yes  Motorcycle      No
# 2    Male      23             2.0    Home   Yes       No          No      No
# 3    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4  Female      19             2.0    Home    No       No  Motorcycle      No
#
#   Consome Alcool Joga Usa Cosmeticos Assinaturas  Gastos Mensais
# 0             No   No            Yes          No           150.0
# 1             No  Yes            Yes         Yes           220.0
# 2             No   No             No         NaN           180.0
# 3             No  Yes            Yes         Yes           200.0
# 4             No   No            Yes          No           300.0

# %%
selecao = (dados['Bolsa'] == 'No') & (dados['Trabalho'] == 'No')
sem_bolsa_sem_trabalho = dados[selecao]
sem_bolsa_sem_trabalho.head()
# Out:
#      Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0   Female      21             2.0    Home    No       No          No      No
# 3     Male      19             3.0  Hostel    No       No  Motorcycle      No
# 4   Female      19             2.0    Home    No       No  Motorcycle      No
# 9     Male      19             1.0    Home    No       No          No     NaN
# 10    Male      22             3.0    Home    No       No         Car      No
#
#    Consome Alcool Joga Usa Cosmeticos Assinaturas  Gastos Mensais
# 0              No   No            Yes          No           150.0
# 3              No  Yes            Yes         Yes           200.0
# 4              No   No            Yes          No           300.0
# 9              No  Yes            Yes         NaN           160.0
# 10             No   No            Yes         Yes           350.0

# %%
sem_bolsa_sem_trabalho.shape[0]
# Out:
# 53

# %%
sem_bolsa_sem_trabalho.index = range(sem_bolsa_sem_trabalho.shape[0])
sem_bolsa_sem_trabalho.head()
# Out:
#     Genero  Idade  Anos de Estudo Moradia Bolsa Trabalho  Transporte Fumante  \
# 0  Female      21             2.0    Home    No       No          No      No
# 1    Male      19             3.0  Hostel    No       No  Motorcycle      No
# 2  Female      19             2.0    Home    No       No  Motorcycle      No
# 3    Male      19             1.0    Home    No       No          No     NaN
# 4    Male      22             3.0    Home    No       No         Car      No
#
#   Consome Alcool Joga Usa Cosmeticos Assinaturas  Gastos Mensais
# 0             No   No            Yes          No           150.0
# 1             No  Yes            Yes         Yes           200.0
# 2             No   No            Yes          No           300.0
# 3             No  Yes            Yes         NaN           160.0
# 4             No   No            Yes         Yes           350.0

# %%
n4 = sem_bolsa_sem_trabalho['Gastos Mensais'].mean()
n4
# Out:
# 213.39622641509433

# %% [markdown]
# # Conclusão

# %%
print("A média de gastos geral é de {}".format(n0))
print("A média de gastos para um bolsista que trabalha é de {}".format(n1))
print("A média de gastos para um bolsista que não trabalha é de {}".format(n2))
print("A média de gastos para um não bolsista que trabalha é de {}".format(n3))
print("A média de gastos para um não bolsista que não trabalha é de {}".format(n4))
# Out:
# A média de gastos geral é de 214.94949494949495
# A média de gastos para um bolsista que trabalha é de 269.09090909090907
# A média de gastos para um bolsista que não trabalha é de 194.28571428571428
# A média de gastos para um não bolsista que trabalha é de 208.75
# A média de gastos para um não bolsista que não trabalha é de 213.39622641509433

# %%
medias = data = [n0, n1, n2, n3, n4]
medias
# Out:
# [214.94949494949495,
#  269.09090909090907,
#  194.28571428571428,
#  208.75,
#  213.39622641509433]

# %%
tabela_medias = pd.DataFrame(medias, 'geral bolsa_e_trabalho bolsa_sem_trabalho trabalho_sem_bolsa sem_bolsa_e_sem_trabalho'.split(), 
                             columns = ['Médias'])
tabela_medias.columns.name = 'Tipo'
tabela_medias
# Out:
# Tipo                          Médias
# geral                     214.949495
# bolsa_e_trabalho          269.090909
# bolsa_sem_trabalho        194.285714
# trabalho_sem_bolsa        208.750000
# sem_bolsa_e_sem_trabalho  213.396226

# %%
tabela_medias = tabela_medias.reset_index()
tabela_medias
# Out:
# Tipo                     index      Médias
# 0                        geral  214.949495
# 1             bolsa_e_trabalho  269.090909
# 2           bolsa_sem_trabalho  194.285714
# 3           trabalho_sem_bolsa  208.750000
# 4     sem_bolsa_e_sem_trabalho  213.396226

# %%
tabela_medias.columns = ('Tipos', 'Media de Gastos')
tabela_medias
# Out:
#                       Tipos  Media de Gastos
# 0                     geral       214.949495
# 1          bolsa_e_trabalho       269.090909
# 2        bolsa_sem_trabalho       194.285714
# 3        trabalho_sem_bolsa       208.750000
# 4  sem_bolsa_e_sem_trabalho       213.396226

# %%
tabela_medias = tabela_medias.sort_values(by = 'Media de Gastos', ascending = False)

# %%
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (12, 5))
x= ['Geral', 'Bolsa e Trabalho', 'Bolsa sem Trabalho', 'Trabalho sem Bolsa', 'Sem Bolsa sem Trabalho']
y= [214, 269, 194, 208, 213]
plt.bar(x, y, width= 0.5, color= 'Maroon')
plt.title('Media de Gastos de Estudantes Com ou Sem Bolsa de Estudos e Trabalho', fontsize = 16)
plt.show()
