# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/preco_comodites.csv')
dados.reset_index()
# Out:
#      index        Date  All Commodity Price Index  Non-Fuel Price Index  \
# 0        0  1980-01-01                        NaN                   NaN
# 1        1  1980-02-01                        NaN                   NaN
# 2        2  1980-03-01                        NaN                   NaN
# 3        3  1980-04-01                        NaN                   NaN
# 4        4  1980-05-01                        NaN                   NaN
# ..     ...         ...                        ...                   ...
# 429    429  2015-10-01                 103.466916            126.907455
# 430    430  2015-11-01                  97.467668            122.040427
# 431    431  2015-12-01                  90.734792            121.669445
# 432    432  2016-01-01                  83.150947            121.295627
# 433    433  2016-02-01                  84.834812            123.006453
#
#      Food and Beverage Price Index  Food Price Index  Beverage Price Index  \
# ...

# %%
dados = dados[['Date', 'All Commodity Price Index', 'Food and Beverage Price Index', 
              'Sugar Free Market', 'Wheat', 'Sunflower oil', 'Agricultural Raw Materials Index'
              ]]

# %%
dados1 = pd.read_csv('dados/preco_comodites_principais.csv')

# %%
dados1.columns
# Out:
# Index(['Date', 'All Commodity Price Index', 'Food and Beverage Price Index',
#        'Sugar Free Market', 'Wheat', 'Sunflower oil',
#        'Agricultural Raw Materials Index'],
#       dtype='object')

# %%
renomear = {'Date': 'data', 'All Commodity Price Index' : 'todas_comodites' , 
            'Food and Beverage Price Index' : 'alimentos_e_bebidas',
       'Sugar Free Market' : 'acucar', 'Wheat' : 'trigo', 'Sunflower oil' : 'oleo_girassol',
       'Agricultural Raw Materials Index' : 'materiais_agricolas'}

# %%
dados1 = dados1.rename(columns = renomear)

# %%
dados1.to_csv('dados/preco_comodites_principais.csv', index = False)
